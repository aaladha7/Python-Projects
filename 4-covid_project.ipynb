# %%
import pandas as pd

# %%
data = pd.read_csv('/Users/aliladha/Desktop/Pandas-Demo/data/Projects/covid.csv')

# %%
data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
data.count()
#shows non null values in each column
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
data.isnull().sum()
#shows # of null columns
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(data.isnull())
#showing null values via a heatmap with seaborn

#the white space shows the null values.
# Out:
# <Axes: >

# %% [markdown]
# __1. Show the number of confirmed,deaths, and recovered cases in each region__

# %%
data.head(2)
#whenever you are asked for each, use groupby (most of the time)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data.groupby('Region')[['Confirmed','Recovered','Deaths']].sum().head(20)
#head 20 was added to see the 20 rows
# Out:
#                      Confirmed  Recovered  Deaths
# Region
# Afghanistan               1939        252      60
# Albania                    766        455      30
# Algeria                   3848       1702     444
# Andorra                    743        423      42
# Angola                      27          7       2
# Antigua and Barbuda         24         11       3
# Argentina                 4285       1192     214
# Armenia                   1932        900      30
# Australia                 6752       5715      91
# Austria                  15402      12779     580
# Azerbaijan                1766       1267      23
# Bahamas                     80         23      11
# Bahrain                   2921       1455       8
# Bangladesh                7103        150     163
# Barbados                    80         39       7
# Belarus                  13181       2072      84
# Belgium                  47859      11283    7501
# Belize                      18          9       2
# ...

# %%
data.groupby('Region')['Confirmed'].sum().sort_values().head(20)
#if you only want to view confirmed cases
# Out:
# Region
# Yemen                                6
# Western Sahara                       6
# Bhutan                               7
# Papua New Guinea                     8
# Sao Tome and Principe                8
# Mauritania                           8
# MS Zaandam                           9
# Gambia                              10
# Holy See                            10
# Suriname                            10
# Burundi                             11
# Seychelles                          11
# Nicaragua                           13
# Saint Kitts and Nevis               15
# Dominica                            16
# Namibia                             16
# Saint Vincent and the Grenadines    16
# Saint Lucia                         17
# Belize                              18
# Fiji                                18
# Name: Confirmed, dtype: int64

# %%
data.groupby('Region')[['Confirmed','Recovered']].sum().head(20)
# Out:
#                      Confirmed  Recovered
# Region
# Afghanistan               1939        252
# Albania                    766        455
# Algeria                   3848       1702
# Andorra                    743        423
# Angola                      27          7
# Antigua and Barbuda         24         11
# Argentina                 4285       1192
# Armenia                   1932        900
# Australia                 6752       5715
# Austria                  15402      12779
# Azerbaijan                1766       1267
# Bahamas                     80         23
# Bahrain                   2921       1455
# Bangladesh                7103        150
# Barbados                    80         39
# Belarus                  13181       2072
# Belgium                  47859      11283
# Belize                      18          9
# Benin                       64         33
# Bhutan                       7          5

# %% [markdown]
# __3. Remove all the records where confirmed cases is less than 10__

# %%
data.head(2)

data['Confirmed']<10
data[data['Confirmed']<10]
data[~(data['Confirmed']<10)].sort_values(by='Confirmed')


data = data[~(data['Confirmed']<10)].sort_values(by='Confirmed')

data
# Out:
#           Date      State    Region  Confirmed  Deaths  Recovered
# 156  4/29/2020        NaN  Suriname         10       1          8
# 70   4/29/2020        NaN  Holy See         10       0          2
# 59   4/29/2020        NaN    Gambia         10       1          8
# 318  4/29/2020      Yukon    Canada         11       0          0
# 217  4/29/2020  Greenland   Denmark         11       0         11
# ..         ...        ...       ...        ...     ...        ...
# 57   4/29/2020        NaN    France     165093   24087      48228
# 168  4/29/2020        NaN        UK     165221   26097          0
# 80   4/29/2020        NaN     Italy     203591   27682      71252
# 153  4/29/2020        NaN     Spain     236899   24275     132929
# 265  4/29/2020   New York        US     299691   23477          0
#
# [304 rows x 6 columns]

# %% [markdown]
# __3. In which Region was the maximum number of Confirmed cases recorded in total__

# %%
data = pd.read_csv('/Users/aliladha/Desktop/Pandas-Demo/data/Projects/covid.csv')
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data.groupby('Region')['Confirmed'].sum().sort_values(ascending=False).head(20)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166543
# UK                 166441
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82862
# Brazil              79685
# Canada              52865
# Belgium             47859
# Netherlands         38998
# Peru                33931
# India               33062
# Switzerland         29407
# Ecuador             24675
# Portugal            24505
# Saudi Arabia        21402
# Name: Confirmed, dtype: int64

# %% [markdown]
# __4. In which Region were the minimum number of deaths recorded in total__

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data.groupby('Region')['Deaths'].sum().sort_values()
# Out:
# Region
# Laos              0
# Mongolia          0
# Mozambique        0
# Cambodia          0
# Fiji              0
#               ...
# France        24121
# Spain         24275
# UK            26166
# Italy         27682
# US            60967
# Name: Deaths, Length: 187, dtype: int64

# %% [markdown]
# __5. How many confirmed deaths and recovered cases were reported from Canada till 29 April 2020__

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data[data['Region']=='Canada']
# Out:
#           Date                         State  Region  Confirmed  Deaths  \
# 183  4/29/2020                       Alberta  Canada       5165      87
# 193  4/29/2020              British Columbia  Canada       2087     109
# 203  4/29/2020  Diamond Princess cruise ship  Canada          0       1
# 215  4/29/2020                Grand Princess  Canada         13       0
# 246  4/29/2020                      Manitoba  Canada        275       6
# 259  4/29/2020                 New Brunswick  Canada        118       0
# 266  4/29/2020     Newfoundland and Labrador  Canada        258       3
# 272  4/29/2020         Northwest Territories  Canada          5       0
# 273  4/29/2020                   Nova Scotia  Canada        935      28
# 276  4/29/2020                       Ontario  Canada      16978    1153
# 279  4/29/2020          Prince Edward Island  Canada         27       0
# 282  4/29/2020                        Quebec  Canada      26610    1762
# ...

# %% [markdown]
# __6a) Sort the entire data with Number of confirmed cases in ascending order__

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data.sort_values(by = ['Confirmed'], ascending=True)
# Out:
#           Date                         State          Region  Confirmed  \
# 285  4/29/2020                     Recovered              US          0
# 284  4/29/2020                     Recovered          Canada          0
# 203  4/29/2020  Diamond Princess cruise ship          Canada          0
# 305  4/29/2020                         Tibet  Mainland China          1
# 289  4/29/2020     Saint Pierre and Miquelon          France          1
# ..         ...                           ...             ...        ...
# 57   4/29/2020                           NaN          France     165093
# 168  4/29/2020                           NaN              UK     165221
# 80   4/29/2020                           NaN           Italy     203591
# 153  4/29/2020                           NaN           Spain     236899
# 265  4/29/2020                      New York              US     299691
#
#      Deaths  Recovered
# 285       0     120720
# 284       0      20327
# 203       1          0
# ...

# %% [markdown]
# __6b) Sort the entire data with Number of Recovered cases in descending order__

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data.sort_values('Recovered', ascending=False)
# Out:
#           Date           State   Region  Confirmed  Deaths  Recovered
# 153  4/29/2020             NaN    Spain     236899   24275     132929
# 285  4/29/2020       Recovered       US          0       0     120720
# 61   4/29/2020             NaN  Germany     161539    6467     120400
# 76   4/29/2020             NaN     Iran      93657    5957      73791
# 80   4/29/2020             NaN    Italy     203591   27682      71252
# ..         ...             ...      ...        ...     ...        ...
# 248  4/29/2020        Maryland       US      20849    1078          0
# 246  4/29/2020        Manitoba   Canada        275       6          0
# 243  4/29/2020       Louisiana       US      27660    1845          0
# 241  4/29/2020        Kentucky       US       4537     234          0
# 215  4/29/2020  Grand Princess   Canada         13       0          0
#
# [321 rows x 6 columns]
